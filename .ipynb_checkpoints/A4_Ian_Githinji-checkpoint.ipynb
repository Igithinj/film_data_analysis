# %% [markdown]
# Import the libraries

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
import nltk as nltk
import string
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn import model_selection, preprocessing, linear_model, naive_bayes, metrics, svm
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# Ensure the plots appear correctly

# %%
# %matplotlib inline

# %% [markdown]
# Hide warnings that may clutter output. Note, only added once code was completed and functionality tested.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. Load the dataset

# %%
imdb = pd.read_csv('imdb_movies.csv', index_col = 0)

# %%
imdb.head()
# Out:
#                                            Title  Year Certification  Runtime  \
# 0                       The Shawshank Redemption  1994            MA      142
# 1                                  The Godfather  1972             R      175
# 2                                The Dark Knight  2008             M      152
# 3                         The Godfather: Part II  1974             M      202
# 4  The Lord of the Rings: The Return of the King  2003             M      201
#
#                        Genre  \
# 0                      Drama
# 1               Crime, Drama
# 2       Action, Crime, Drama
# 3               Crime, Drama
# 4  Adventure, Drama, Fantasy
#
#                                              Summary    Votes  Ratings
# 0  Two imprisoned men bond over a number of years...  2164040      9.3
# 1  The aging patriarch of an organized crime dyna...  1485485      9.2
# 2  When the menace known as the Joker wreaks havo...  2138907      9.0
# 3  The early life and career of Vito Corleone in ...  1034512      9.0
# 4  Gandalf and Aragorn lead the World of Men agai...  1536487      8.9

# %% [markdown]
# ## 2. Data Cleansing

# %% [markdown]
# Drop all the rows that contain null values

# %%
imdb.dropna()
# Out:
#                                                  Title  Year Certification  \
# 0                             The Shawshank Redemption  1994            MA
# 1                                        The Godfather  1972             R
# 2                                      The Dark Knight  2008             M
# 3                               The Godfather: Part II  1974             M
# 4        The Lord of the Rings: The Return of the King  2003             M
# 5                                         Pulp Fiction  1994             R
# 6                                     Schindler's List  1993             M
# 7                                         12 Angry Men  1957             G
# 8                                            Inception  2010             M
# 9                                           Fight Club  1999             R
# 10   The Lord of the Rings: The Fellowship of the Ring  2001             M
# 11                                        Forrest Gump  1994             M
# 12                      The Good, the Bad and the Ugly  1966             A
# 13                                               Joker  2019         MA15+
# 14               The Lord of the Rings: The Two Towers  2002             M
# 15                                          The Matrix  1999             M
# 16                                          Goodfellas  1990             R
# 17      Star Wars: Episode V - The Empire Strikes Back  1980           NRC
# 18                     One Flew Over the Cuckoo's Nest  1975             M
# 20                                            Parasite  2019         MA15+
# 22                                        Interstellar  2014             M
# 23                                      Cidade de Deus  2002             R
# 24                                       Spirited Away  2001            PG
# 25                                 Saving Private Ryan  1998             R
# 26                                      The Green Mile  1999            MA
# 27                                   Life Is Beautiful  1997             M
# 28                                               Se7en  1995             R
# 29                            The Silence of the Lambs  1991             R
# 30                                           Star Wars  1977           NRC
# 31                                       Seven Samurai  1954            PG
# ..                                                 ...   ...           ...
# 970                                          Mad Max 2  1981             R
# 971                                       The Warriors  1979             R
# 972                                   The Muppet Movie  1979             G
# 973                               Escape from Alcatraz  1979             M
# 974                                     Watership Down  1978           NRC
# 975                                   Midnight Express  1978             R
# 976                 Close Encounters of the Third Kind  1977           NRC
# 977                                     Profondo rosso  1975             R
# 978                                         Robin Hood  1973             G
# 979         And Now for Something Completely Different  1971           NRC
# 980                                     Little Big Man  1970           SOA
# 981                                     Kelly's Heroes  1970             A
# 982                                      The Producers  1967             G
# 983                                    The Jungle Book  1967             G
# 984                                             Blowup  1966             A
# 985                                     Pierrot le fou  1965             M
# 986                                 A Hard Day's Night  1964             G
# 987                                          Le mépris  1963           SOA
# 988                           Stanley Kubrick's Lolita  1962             A
# 989                                              Giant  1956             G
# 990                                              Shane  1953             G
# 991                              From Here to Eternity  1953             A
# 992                    Snow White and the Seven Dwarfs  1937             G
# 993                                           The Town  2010         MA15+
# 994                                      Kung Fu Panda  2008            PG
# 995                                             Munich  2005         MA15+
# 996                                Kiss Kiss Bang Bang  2005         MA15+
# 997                                  Gangs of New York  2002            MA
# 998                                            RoboCop  1987             R
# 999                                            The Fly  1986             R
#
#      Runtime                         Genre  \
# 0        142                         Drama
# 1        175                  Crime, Drama
# 2        152          Action, Crime, Drama
# 3        202                  Crime, Drama
# 4        201     Adventure, Drama, Fantasy
# 5        154                  Crime, Drama
# 6        195     Biography, Drama, History
# 7         96                         Drama
# 8        148     Action, Adventure, Sci-Fi
# 9        139                         Drama
# 10       178     Adventure, Drama, Fantasy
# 11       142                Drama, Romance
# 12       161                       Western
# 13       122        Crime, Drama, Thriller
# 14       179     Adventure, Drama, Fantasy
# 15       136                Action, Sci-Fi
# 16       146       Biography, Crime, Drama
# 17       124    Action, Adventure, Fantasy
# 18       133                         Drama
# 20       132       Comedy, Drama, Thriller
# 22       169      Adventure, Drama, Sci-Fi
# 23       130                  Crime, Drama
# 24       125  Animation, Adventure, Family
# 25       169                    Drama, War
# 26       189         Crime, Drama, Fantasy
# 27       116        Comedy, Drama, Romance
# 28       127         Crime, Drama, Mystery
# 29       118        Crime, Drama, Thriller
# 30       121    Action, Adventure, Fantasy
# 31       207      Action, Adventure, Drama
# ..       ...                           ...
# 970       96     Action, Adventure, Sci-Fi
# 971       92       Action, Crime, Thriller
# 972       95     Adventure, Comedy, Family
# 973      112       Biography, Crime, Drama
# 974       91   Animation, Adventure, Drama
# 975      121       Biography, Crime, Drama
# 976      138                 Drama, Sci-Fi
# 977      127     Horror, Mystery, Thriller
# 978       83  Animation, Adventure, Comedy
# 979       88                        Comedy
# 980      139      Adventure, Comedy, Drama
# 981      144        Adventure, Comedy, War
# 982       88                 Comedy, Music
# 983       78  Animation, Adventure, Family
# 984      111      Drama, Mystery, Thriller
# 985      110         Crime, Drama, Romance
# 986       87        Comedy, Music, Musical
# 987      103                Drama, Romance
# 988      153         Crime, Drama, Romance
# 989      201                Drama, Western
# 990      118                Drama, Western
# 991      118           Drama, Romance, War
# 992       83    Animation, Family, Fantasy
# 993      125        Crime, Drama, Thriller
# 994       92  Animation, Action, Adventure
# 995      164       Biography, Crime, Drama
# 996      103         Action, Comedy, Crime
# 997      167                  Crime, Drama
# 998      102         Action, Crime, Sci-Fi
# 999       96         Drama, Horror, Sci-Fi
#
#                                                Summary    Votes  Ratings
# 0    Two imprisoned men bond over a number of years...  2164040      9.3
# 1    The aging patriarch of an organized crime dyna...  1485485      9.2
# 2    When the menace known as the Joker wreaks havo...  2138907      9.0
# 3    The early life and career of Vito Corleone in ...  1034512      9.0
# 4    Gandalf and Aragorn lead the World of Men agai...  1536487      8.9
# 5    The lives of two mob hitmen, a boxer, a gangst...  1698837      8.9
# 6    In German-occupied Poland during World War II,...  1122674      8.9
# 7    A jury holdout attempts to prevent a miscarria...   619233      8.9
# 8    A thief who steals corporate secrets through t...  1896880      8.8
# 9    An insomniac office worker and a devil-may-car...  1728920      8.8
# 10   A meek Hobbit from the Shire and eight compani...  1551743      8.8
# 11   The presidencies of Kennedy and Johnson, the e...  1666391      8.8
# 12   A bounty hunting scam joins two men in an unea...   642238      8.8
# 13   In Gotham City, mentally troubled comedian Art...   498637      8.7
# 14   While Frodo and Sam edge closer to Mordor with...  1389811      8.7
# 15   A computer hacker learns from mysterious rebel...  1557744      8.7
# 16   The story of Henry Hill and his life in the mo...   936643      8.7
# 17   After the Rebels are brutally overpowered by t...  1081205      8.7
# 18   A criminal pleads insanity and is admitted to ...   854457      8.7
# 20   All unemployed, Ki-taek and his family take pe...    86228      8.6
# 22   A team of explorers travel through a wormhole ...  1351780      8.6
# 23   In the slums of Rio, two kids' paths diverge a...   660370      8.6
# 24   During her family's move to the suburbs, a sul...   578458      8.6
# 25   Following the Normandy Landings, a group of U....  1146208      8.6
# 26   The lives of guards on Death Row are affected ...  1052677      8.6
# 27   When an open-minded Jewish librarian and his s...   572099      8.6
# 28   Two detectives, a rookie and a veteran, hunt a...  1330383      8.6
# 29   A young F.B.I. cadet must receive the help of ...  1172435      8.6
# 30   Luke Skywalker joins forces with a Jedi Knight...  1149813      8.6
# 31   A poor village under attack by bandits recruit...   292865      8.6
# ..                                                 ...      ...      ...
# 970  In the post-apocalyptic Australian wasteland, ...   157843      7.6
# 971  In the near future, a charismatic leader summo...    87725      7.6
# 972  Kermit and his newfound friends trek across Am...    30283      7.6
# 973  Alcatraz is the most secure prison of its time...   107722      7.6
# 974  A group of rabbits flee their doomed warren an...    31713      7.6
# 975  Billy Hayes (Brad Davis), an American college ...    67650      7.6
# 976  Roy Neary, an electric lineman, watches how hi...   171591      7.6
# 977  A jazz pianist and a wisecracking journalist a...    28719      7.6
# 978  The story of the legendary outlaw is portrayed...   106974      7.6
# 979  An anthology of the best sketches from the fir...    27696      7.6
# 980  Jack Crabb, looking back from extreme old age,...    31133      7.6
# 981  A group of U.S. soldiers sneaks across enemy l...    42452      7.6
# 982  Producers Max Bialystock and Leo Bloom make mo...    47226      7.6
# 983  Bagheera the Panther and Baloo the Bear have a...   155105      7.6
# 984  A mod London photographer finds something very...    52108      7.6
# 985  Pierrot escapes his boring society and travels...    25999      7.6
# 986  Over two "typical" days in the life ofThe Beat...    37695      7.6
# 987  Screenwriter Paul Javal's marriage to his wife...    25636      7.6
# 988  A middle-aged college professor becomes infatu...    85554      7.6
# 989  Sprawling epic covering the life of a Texas ca...    31883      7.6
# 990  A weary gunfighter attempts to settle down wit...    34359      7.6
# 991  In Hawaii in 1941, a private is cruelly punish...    40291      7.6
# 992  Exiled into the dangerous forest by her wicked...   169150      7.6
# 993  As he plans his next job, a longtime thief tri...   329578      7.5
# 994  The Dragon Warrior has to clash against the sa...   392235      7.5
# 995  Based on the true story of the Black September...   201658      7.5
# 996  A murder mystery brings together a private eye...   205502      7.5
# 997  In 1862, Amsterdam Vallon returns to the Five ...   380693      7.5
# 998  In a dystopic and crime-ridden Detroit, a term...   219216      7.5
# 999  A brilliant but eccentric scientist begins to ...   148821      7.5
#
# [973 rows x 8 columns]

# %% [markdown]
# Generate a list with all the column names

# %%
column_names = list(imdb.columns)
print(column_names)
# Out:
# ['Title', 'Year', 'Certification', 'Runtime', 'Genre', 'Summary', 'Votes', 'Ratings']

# %% [markdown]
# ## 3. Exploratory Data Analysis

# %% [markdown]
# First, we look at the effect of each of the independent variables on the target variable

# %%
sns.lmplot(x = 'Votes', y = 'Ratings', data = imdb, fit_reg = True)
plt.title('Effect of number of Votes on Ratings')
plt.savefig('Votes_vs_Ratings.jpeg') # Save the resulting plot for use in the final report

# %%
sns.boxplot(x = 'Certification', y = 'Ratings', data = imdb)
plt.title('Effect of Movie Certification on Ratings')
plt.savefig('Certification_vs_Ratings.png') # Save the resulting plot for use in the final report

# %%
sns.lmplot(x = 'Year', y = 'Ratings', data = imdb, fit_reg = False)
plt.title('Effect of Year on Ratings')
plt.savefig('Ratings_by_Year.png') # Save the resulting plot for use in the final report

# %%
sns.distplot(imdb['Ratings'], color = 'Red')
plt.title('Distribution of the Ratings')
plt.savefig('Ratings_distribution.png') # Save the resulting plot for use in the final report

# %%
sns.distplot(imdb['Runtime'])
plt.title('Distribution of the movie Runtime')
plt.savefig('Runtime_distribution.png') # Save the resulting plot for use in the final report

# %% [markdown]
# ## 4. NLP Analysis

# %% [markdown]
# ### 1. Pre-Processing Text

# %% [markdown]
# Create the dataset specific to the NLP analysis

# %%
movies = imdb[['Summary', 'Ratings']]
movies.head()
# Out:
#                                              Summary  Ratings
# 0  Two imprisoned men bond over a number of years...      9.3
# 1  The aging patriarch of an organized crime dyna...      9.2
# 2  When the menace known as the Joker wreaks havo...      9.0
# 3  The early life and career of Vito Corleone in ...      9.0
# 4  Gandalf and Aragorn lead the World of Men agai...      8.9

# %% [markdown]
# The standard stopword list may need to be extended with new stopwords based on the analysis. These are added below:

# %%
stopwords = nltk.corpus.stopwords.words('english')
additional_stopwords = ["'", "'s"]
stopwords.extend(additional_stopwords)

# %% [markdown]
# Define functions to clean the text

# %%
def token(text):
    tokens = word_tokenize(text)
    return tokens

def remove_punctuation(text):
    new_list = []
    for word in text:
        if word not in string.punctuation:
            new_list.append(word)
    return new_list
            
def no_numbers(text):
    new_list = []
    for word in text:
        if not word.isdigit():
            new_list.append(word)
    return new_list

def remove_stopwords(text):
    new_list = []
    for word in text:
        if word not in stopwords:
            new_list.append(word)
    return new_list

def lemmatize_words(text):
    lemmatizer = WordNetLemmatizer()
    lem_text = [lemmatizer.lemmatize(word) for word in text]
    return lem_text

def cleaner(text):
    clean_text = text.lower()
    clean_text = token(clean_text)
    clean_text = remove_punctuation(clean_text)
    clean_text = no_numbers(clean_text)
    clean_text = remove_stopwords(clean_text)
    clean_text = lemmatize_words(clean_text)
    return clean_text

# %% [markdown]
# Create a single list with the complete text

# %%
complete_text = ''
for row in imdb['Summary']:
    complete_text = complete_text + row

# %% [markdown]
# Use the functions to clean the text

# %%
clean_text = cleaner(complete_text)

# %% [markdown]
# Explore the distribution of the words in the complete text

# %%
word_distribution = nltk.FreqDist(clean_text)
word_distribution.most_common(10)
# Out:
# [('young', 126),
#  ('life', 125),
#  ('man', 114),
#  ('find', 104),
#  ('woman', 75),
#  ('new', 72),
#  ('two', 68),
#  ('family', 64),
#  ('world', 64),
#  ('story', 62)]

# %%
word_distribution.plot(20, cumulative = False)
plt.show()

# %% [markdown]
# Create a vectoriser object and fit it to the complete text vocabulary

# %%
vec = CountVectorizer(max_features = 75, analyzer = 'word', tokenizer = None, lowercase = False)
vec.fit_transform(clean_text)
# Out:
# <14411x75 sparse matrix of type '<class 'numpy.int64'>'
# 	with 3382 stored elements in Compressed Sparse Row format>

# %%
vec.get_feature_names()
# Out:
# ['after',
#  'agent',
#  'american',
#  'an',
#  'attempt',
#  'back',
#  'becomes',
#  'boy',
#  'child',
#  'city',
#  'crime',
#  'daughter',
#  'day',
#  'death',
#  'fall',
#  'family',
#  'father',
#  'fight',
#  'find',
#  'first',
#  'force',
#  'former',
#  'friend',
#  'get',
#  'girl',
#  'go',
#  'group',
#  'help',
#  'high',
#  'home',
#  'ii',
#  'in',
#  'lead',
#  'life',
#  'love',
#  'make',
#  'man',
#  'men',
#  'mother',
#  'murder',
#  'must',
#  'mysterious',
#  'new',
#  'old',
#  'one',
#  'order',
#  'past',
#  'people',
#  'police',
#  'return',
#  'school',
#  'search',
#  'set',
#  'small',
#  'soldier',
#  'son',
#  'story',
#  'struggle',
#  'take',
#  'team',
#  'the',
#  'three',
#  'time',
#  'town',
#  'try',
#  'two',
#  'war',
#  'way',
#  'when',
#  'wife',
#  'woman',
#  'work',
#  'world',
#  'year',
#  'young']

# %%
clean_summary = []
for element in movies['Summary']:
    clean_element = cleaner(element)
    clean_summary.append(clean_element)
    
movies['Description'] = clean_summary

# %%
movies.head()
# Out:
#                                              Summary  Ratings  \
# 0  Two imprisoned men bond over a number of years...      9.3
# 1  The aging patriarch of an organized crime dyna...      9.2
# 2  When the menace known as the Joker wreaks havo...      9.0
# 3  The early life and career of Vito Corleone in ...      9.0
# 4  Gandalf and Aragorn lead the World of Men agai...      8.9
#
#                                          Description
# 0  [two, imprisoned, men, bond, number, year, fin...
# 1  [aging, patriarch, organized, crime, dynasty, ...
# 2  [menace, known, joker, wreaks, havoc, chaos, p...
# 3  [early, life, career, vito, corleone, 1920s, n...
# 4  [gandalf, aragorn, lead, world, men, sauron, a...

# %%
ratings_class = []
for element in movies['Ratings']:
    if element >= 7 and element < 8:
        result = 'Good'
        ratings_class.append(result)
    if element >= 8  and element < 9:
        result = 'Great'
        ratings_class.append(result)
    if element >= 9:
        result = 'Excellent'
        ratings_class.append(result)

# %%
movies['Ratings_Class'] = ratings_class
movies.head()
# Out:
#                                              Summary  Ratings  \
# 0  Two imprisoned men bond over a number of years...      9.3
# 1  The aging patriarch of an organized crime dyna...      9.2
# 2  When the menace known as the Joker wreaks havo...      9.0
# 3  The early life and career of Vito Corleone in ...      9.0
# 4  Gandalf and Aragorn lead the World of Men agai...      8.9
#
#                                          Description Ratings_Class
# 0  [two, imprisoned, men, bond, number, year, fin...     Excellent
# 1  [aging, patriarch, organized, crime, dynasty, ...     Excellent
# 2  [menace, known, joker, wreaks, havoc, chaos, p...     Excellent
# 3  [early, life, career, vito, corleone, 1920s, n...     Excellent
# 4  [gandalf, aragorn, lead, world, men, sauron, a...         Great

# %%
movies['Ratings_Class'].value_counts()
# Out:
# Good         556
# Great        440
# Excellent      4
# Name: Ratings_Class, dtype: int64

# %% [markdown]
# Rebalance the classes due to the imbalance existing in the Ratings Class above

# %%
from sklearn.utils import resample
# Separate majority and minority classes
movies_majority = movies[(movies.Ratings_Class == 'Good')]
movies_minority_1 = movies[movies.Ratings_Class == 'Great']
movies_minority_2 = movies[movies.Ratings_Class == 'Excellent'] 
    
# Upsample minority class
movies_minority_1_upsampled = resample(movies_minority_1, replace=True, n_samples=556, random_state=123)  
movies_minority_2_upsampled = resample(movies_minority_2, replace=True, n_samples=556, random_state=123) 

# Combine majority class with upsampled minority class
movies_fixed = pd.concat([movies_majority, movies_minority_1_upsampled, movies_minority_2_upsampled ])
 
# Display new class counts
movies_fixed.Ratings_Class.value_counts()
# Out:
# Excellent    556
# Good         556
# Great        556
# Name: Ratings_Class, dtype: int64

# %%
movies_fixed.head()
# Out:
#                                                Summary  Ratings  \
# 444  A faded television actor and his stunt double ...      7.9
# 445  In 1980s Italy, a romance blossoms between a s...      7.9
# 446  After having suffered a heart-attack, a 59-yea...      7.9
# 447  Set in Japan, Isle of Dogs follows a boy's ody...      7.9
# 448  Allied soldiers from Belgium, the British Empi...      7.9
#
#                                            Description Ratings_Class
# 444  [faded, television, actor, stunt, double, stri...          Good
# 445  [1980s, italy, romance, blossom, seventeen-yea...          Good
# 446  [suffered, heart-attack, 59-year-old, carpente...          Good
# 447  [set, japan, isle, dog, follows, boy, odyssey,...          Good
# 448  [allied, soldier, belgium, british, empire, fr...          Good

# %% [markdown]
# ### 2. Feature Engineering

# %% [markdown]
# Split the dataset into training and validation datasets

# %%
train_x, valid_x, train_y, valid_y = model_selection.train_test_split(movies_fixed['Description'], movies_fixed['Ratings_Class'], 
                                                                      test_size = 0.30)

# %% [markdown]
# Transform the text

# %%
train_x_vec = vec.transform(train_x.astype('str'))
valid_x_vec = vec.transform(valid_x.astype('str'))

# %% [markdown]
# ### 3. Model Building

# %%
svclassifier = svm.SVC(kernel='rbf')
svclassifier.fit(train_x_vec, train_y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %% [markdown]
# ### 4. Model Evaluation

# %% [markdown]
# Use the model to predict the validation set

# %%
predicted_class = svclassifier.predict(valid_x_vec)

# %% [markdown]
# Assess the performance of the model

# %%
print(confusion_matrix(valid_y, predicted_class))
print(classification_report(valid_y, predicted_class))
# Out:
# [[169   0   0]
#  [  4 148   0]
#  [  2 177   1]]
#              precision    recall  f1-score   support
#
#   Excellent       0.97      1.00      0.98       169
#        Good       0.46      0.97      0.62       152
#       Great       1.00      0.01      0.01       180
#
# avg / total       0.82      0.63      0.52       501
